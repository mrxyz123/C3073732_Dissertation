# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path = 'Primary_DataSet_Raw.csv'

primary_df = pd.read_csv(file_path)

# %%
primary_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 1  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 2           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 3                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 4                                   Rural population        SP.RUR.TOTL
#
#         1960          1961          1962        1963          1964  \
# 0        NaN           NaN           NaN         NaN           NaN
# 1        NaN           NaN           NaN         NaN           NaN
# 2     49.224     49.239000     49.254000     49.2700     49.285000
# 3        NaN      2.211234      1.577679      1.4226      1.245827
# ...

# %%
secondary_file_path = 'Country_Abbr.csv'

# Read the secondary CSV file
secondary_df = pd.read_csv(secondary_file_path)
secondary_df.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# ...

# %%
# Perform the anti join to find records in df1 that do not have a match in df2
df_not_country = primary_df[~primary_df['Country Code'].isin(secondary_df['alpha-3'])]
df_not_country.head()
# Out:
#                    Country Name Country Code  \
# 42  Africa Eastern and Southern          AFE
# 43  Africa Eastern and Southern          AFE
# 44  Africa Eastern and Southern          AFE
# 45  Africa Eastern and Southern          AFE
# 46  Africa Eastern and Southern          AFE
#
#                                        Indicator Name     Indicator Code  \
# 42  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 43  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 44           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 45                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 46                                   Rural population        SP.RUR.TOTL
#
#             1960          1961          1962          1963          1964  \
# 42           NaN           NaN           NaN           NaN           NaN
# 43           NaN           NaN           NaN           NaN           NaN
# ...

# %%
# Find the unique unqualified country or organisation 
df_not_country['Country Name'].unique()
# Out:
# array(['Africa Eastern and Southern', 'Africa Western and Central',
#        'Arab World', 'Central Europe and the Baltics', 'Channel Islands',
#        'Caribbean small states',
#        'East Asia & Pacific (excluding high income)',
#        'Early-demographic dividend', 'East Asia & Pacific',
#        'Europe & Central Asia (excluding high income)',
#        'Europe & Central Asia', 'Euro area', 'European Union',
#        'Fragile and conflict affected situations', 'High income',
#        'Heavily indebted poor countries (HIPC)', 'IBRD only',
#        'IDA & IBRD total', 'IDA total', 'IDA blend', 'IDA only',
#        'Not classified',
#        'Latin America & Caribbean (excluding high income)',
#        'Latin America & Caribbean',
#        'Least developed countries: UN classification', 'Low income',
#        'Lower middle income', 'Low & middle income',
#        'Late-demographic dividend', 'Middle East & North Africa',
#        'Middle income',
# ...

# %%
# Find the common keys
common_keys = primary_df['Country Code'].isin(secondary_df['alpha-3'])

# Keep only the records from df1 that have a match in df2
df = primary_df[common_keys]
df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 1  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 2           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 3                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 4                                   Rural population        SP.RUR.TOTL
#
#         1960          1961          1962        1963          1964  \
# 0        NaN           NaN           NaN         NaN           NaN
# 1        NaN           NaN           NaN         NaN           NaN
# 2     49.224     49.239000     49.254000     49.2700     49.285000
# 3        NaN      2.211234      1.577679      1.4226      1.245827
# ...

# %%
df = pd.DataFrame(df)

# Select columns from 2 to 5 (inclusive) and 9 to 11 (inclusive)
final_df = pd.concat([df.iloc[:, 0:4], df.iloc[:, -25:]], axis=1)

final_df.head()
# Out:
#   Country Name Country Code  \
# 0        Aruba          ABW
# 1        Aruba          ABW
# 2        Aruba          ABW
# 3        Aruba          ABW
# 4        Aruba          ABW
#
#                                       Indicator Name     Indicator Code  \
# 0  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 1  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 2           Rural population (% of total population)     SP.RUR.TOTL.ZS
# 3                 Rural population growth (annual %)     SP.RUR.TOTL.ZG
# 4                                   Rural population        SP.RUR.TOTL
#
#            1999          2000          2001          2002          2003  \
# 0           NaN      0.737147      0.548675      0.992986      1.171996
# 1           NaN      2.944628      2.513892      2.516782      2.677284
# 2     52.873000     53.283000     53.661000     54.028000     54.394000
# ...

# %%
final_df.to_csv('final_df.csv', index=False)

# %% [markdown]
# # Agricultural raw materials exports (% of merchandise exports)

# %%
agricultural_raw_materials_exports_subset = final_df[final_df['Indicator Name'] == 'Agricultural raw materials exports (% of merchandise exports)']

# Exporting the DataFrame to a CSV file
agricultural_raw_materials_exports_subset.to_csv('agricultural_raw_materials_exports_subset.csv', index=False)

# %%
agricultural_raw_materials_exports_subset.head(5)
# Out:
#     Country Name Country Code  \
# 0          Aruba          ABW
# 84   Afghanistan          AFG
# 168       Angola          AGO
# 210      Albania          ALB
# 252      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 0    Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 84   Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 168  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 210  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
# 252  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
#
#          1999      2000      2001      2002      2003      2004  ...  \
# 0         NaN  0.737147  0.548675  0.992986  1.171996  1.248594  ...
# 84        NaN       NaN       NaN       NaN       NaN       NaN  ...
# 168       NaN       NaN       NaN       NaN       NaN       NaN  ...
# ...

# %% [markdown]
# # Agricultural raw materials imports (% of merchandise imports)

# %%
agricultural_raw_materials_imports_subset = final_df[final_df['Indicator Name'] == 'Agricultural raw materials imports (% of merchandise imports)']

# Exporting the DataFrame to a CSV file
agricultural_raw_materials_imports_subset.to_csv('agricultural_raw_materials_imports_subset.csv', index=False)

# %%
agricultural_raw_materials_imports_subset.head(5)
# Out:
#     Country Name Country Code  \
# 1          Aruba          ABW
# 85   Afghanistan          AFG
# 169       Angola          AGO
# 211      Albania          ALB
# 253      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 1    Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 85   Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 169  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 211  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
# 253  Agricultural raw materials imports (% of merch...  TM.VAL.AGRI.ZS.UN
#
#          1999      2000      2001      2002      2003      2004  ...  \
# 1         NaN  2.944628  2.513892  2.516782  2.677284  2.773688  ...
# 85        NaN       NaN       NaN       NaN       NaN       NaN  ...
# 169       NaN       NaN       NaN       NaN       NaN       NaN  ...
# ...

# %% [markdown]
# # Rural population (% of total population)

# %%
rural_population_percent = final_df[final_df['Indicator Name'] == 'Rural population (% of total population)']

# Exporting the DataFrame to a CSV file
rural_population_percent.to_csv('rural_population_percent.csv', index=False)

# %%
rural_population_percent.head(5)
# Out:
#     Country Name Country Code                            Indicator Name  \
# 2          Aruba          ABW  Rural population (% of total population)
# 86   Afghanistan          AFG  Rural population (% of total population)
# 170       Angola          AGO  Rural population (% of total population)
# 212      Albania          ALB  Rural population (% of total population)
# 254      Andorra          AND  Rural population (% of total population)
#
#      Indicator Code    1999    2000    2001    2002    2003    2004  ...  \
# 2    SP.RUR.TOTL.ZS  52.873  53.283  53.661  54.028  54.394  54.760  ...
# 86   SP.RUR.TOTL.ZS  78.014  77.922  77.831  77.739  77.647  77.500  ...
# 170  SP.RUR.TOTL.ZS  51.103  49.913  48.726  47.539  46.355  45.173  ...
# 212  SP.RUR.TOTL.ZS  58.831  58.259  57.565  56.499  55.427  54.349  ...
# 254  SP.RUR.TOTL.ZS   7.334   7.605   7.944   8.359   8.793   9.249  ...
#
#        2014    2015    2016    2017    2018    2019    2020    2021    2022  \
# ...

# %% [markdown]
# # Rural population growth (annual %)

# %%
rural_population_growth_percent = final_df[final_df['Indicator Name'] == 'Rural population growth (annual %)']

# Exporting the DataFrame to a CSV file
rural_population_growth_percent.to_csv('rural_population_growth_percent.csv', index=False)

# %%
rural_population_growth_percent.head(5)
# Out:
#     Country Name Country Code                      Indicator Name  \
# 3          Aruba          ABW  Rural population growth (annual %)
# 87   Afghanistan          AFG  Rural population growth (annual %)
# 171       Angola          AGO  Rural population growth (annual %)
# 213      Albania          ALB  Rural population growth (annual %)
# 255      Andorra          AND  Rural population growth (annual %)
#
#      Indicator Code      1999      2000      2001      2002      2003  \
# 3    SP.RUR.TOTL.ZG  3.710577  3.312759  2.475631  1.874807  1.673855
# 87   SP.RUR.TOTL.ZG  3.961297  1.325806  0.625667  6.331048  7.422604
# 171  SP.RUR.TOTL.ZG  0.930257  0.887947  0.878351  0.868890  0.891202
# 213  SP.RUR.TOTL.ZG -1.594234 -1.614394 -2.136818 -2.169089 -2.289749
# 255  SP.RUR.TOTL.ZG  4.329129  4.308734  6.935087  9.449997  9.297409
#
#          2004  ...      2014      2015      2016      2017      2018  \
# 3    1.572140  ...  0.601746  0.520623  0.442423  0.358555  0.287256
# ...

# %% [markdown]
# # Rural population

# %%
rural_population_total = final_df[final_df['Indicator Name'] == 'Rural population']

# Exporting the DataFrame to a CSV file
rural_population_total.to_csv('rural_population_total.csv', index=False)

# %%
rural_population_total.head(5)
# Out:
#     Country Name Country Code    Indicator Name Indicator Code        1999  \
# 4          Aruba          ABW  Rural population    SP.RUR.TOTL     45929.0
# 88   Afghanistan          AFG  Rural population    SP.RUR.TOTL  15027717.0
# 172       Angola          AGO  Rural population    SP.RUR.TOTL   8110431.0
# 214      Albania          ALB  Rural population    SP.RUR.TOTL   1828925.0
# 256      Andorra          AND  Rural population    SP.RUR.TOTL      4815.0
#
#            2000        2001        2002        2003        2004  ...  \
# 4       47476.0     48666.0     49587.0     50424.0     51223.0  ...
# 88   15228282.0  15323859.0  16325389.0  17583264.0  18254002.0  ...
# 172   8182768.0   8254958.0   8326997.0   8401539.0   8479480.0  ...
# 214   1799636.0   1761589.0   1723790.0   1684768.0   1645111.0  ...
# 256      5027.0      5388.0      5922.0      6499.0      7116.0  ...
#
#            2014        2015        2016        2017        2018        2019  \
# ...

# %% [markdown]
# # Employment in agriculture (% of total employment)

# %%
employment_agriculture_percent = final_df[final_df['Indicator Name'] == 'Employment in agriculture (% of total employment) (modeled ILO estimate)']

# Exporting the DataFrame to a CSV file
employment_agriculture_percent.to_csv('employment_agriculture_percent.csv', index=False)

# %%
employment_agriculture_percent.head(5)
# Out:
#     Country Name Country Code  \
# 5          Aruba          ABW
# 89   Afghanistan          AFG
# 173       Angola          AGO
# 215      Albania          ALB
# 257      Andorra          AND
#
#                                         Indicator Name  Indicator Code  \
# 5    Employment in agriculture (% of total employme...  SL.AGR.EMPL.ZS
# 89   Employment in agriculture (% of total employme...  SL.AGR.EMPL.ZS
# 173  Employment in agriculture (% of total employme...  SL.AGR.EMPL.ZS
# 215  Employment in agriculture (% of total employme...  SL.AGR.EMPL.ZS
# 257  Employment in agriculture (% of total employme...  SL.AGR.EMPL.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 5          NaN        NaN        NaN        NaN        NaN        NaN  ...
# 89   65.354736  65.347961  65.254189  63.931615  63.256091  62.640624  ...
# 173  37.572140  37.146007  36.925144  36.425849  36.155572  36.166335  ...
# ...

# %% [markdown]
# # Employment in agriculture, male (% of male employment)

# %%
employment_agriculture_male_percent = final_df[final_df['Indicator Name'] == 'Employment in agriculture, male (% of male employment) (modeled ILO estimate)']

# Exporting the DataFrame to a CSV file
employment_agriculture_male_percent.to_csv('employment_agriculture_male_percent.csv', index=False)

# %%
employment_agriculture_male_percent.head(5)
# Out:
#     Country Name Country Code  \
# 6          Aruba          ABW
# 90   Afghanistan          AFG
# 174       Angola          AGO
# 216      Albania          ALB
# 258      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 6    Employment in agriculture, male (% of male emp...  SL.AGR.EMPL.MA.ZS
# 90   Employment in agriculture, male (% of male emp...  SL.AGR.EMPL.MA.ZS
# 174  Employment in agriculture, male (% of male emp...  SL.AGR.EMPL.MA.ZS
# 216  Employment in agriculture, male (% of male emp...  SL.AGR.EMPL.MA.ZS
# 258  Employment in agriculture, male (% of male emp...  SL.AGR.EMPL.MA.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 6          NaN        NaN        NaN        NaN        NaN        NaN  ...
# 90   61.417190  61.387835  61.198097  59.885634  59.179138  58.463534  ...
# 174  28.465790  28.133324  27.993870  28.206276  27.710619  28.239912  ...
# ...

# %% [markdown]
# # Employment in agriculture, female (% of female employment)

# %%
employment_agriculture_female_percent = final_df[final_df['Indicator Name'] == 'Employment in agriculture, female (% of female employment) (modeled ILO estimate)']

# Exporting the DataFrame to a CSV file
employment_agriculture_female_percent.to_csv('employment_agriculture_female_percent.csv', index=False)

# %%
employment_agriculture_female_percent.head(5)
# Out:
#     Country Name Country Code  \
# 7          Aruba          ABW
# 91   Afghanistan          AFG
# 175       Angola          AGO
# 217      Albania          ALB
# 259      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 7    Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
# 91   Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
# 175  Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
# 217  Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
# 259  Employment in agriculture, female (% of female...  SL.AGR.EMPL.FE.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 7          NaN        NaN        NaN        NaN        NaN        NaN  ...
# 91   85.809153  86.041096  86.287865  84.692672  83.945842  83.624794  ...
# 175  46.950233  46.407761  46.098336  44.852876  44.811969  44.289331  ...
# ...

# %% [markdown]
# # Agriculture, forestry, and fishing, value added (% of GDP)

# %%
agriculture_value_added_percent_gdp = final_df[final_df['Indicator Name'] == 'Agriculture, forestry, and fishing, value added (% of GDP)']

# Exporting the DataFrame to a CSV file
agriculture_value_added_percent_gdp.to_csv('agriculture_value_added_percent_gdp.csv', index=False)

# %%
agriculture_value_added_percent_gdp.head(5)
# Out:
#     Country Name Country Code  \
# 8          Aruba          ABW
# 92   Afghanistan          AFG
# 176       Angola          AGO
# 218      Albania          ALB
# 260      Andorra          AND
#
#                                         Indicator Name  Indicator Code  \
# 8    Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 92   Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 176  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 218  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 260  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 8     0.383268   0.018608   0.018617   0.018054   0.018011   0.017566  ...
# 92         NaN        NaN        NaN  38.627892  37.418855  29.721067  ...
# 176   6.290257   5.664690   8.156377   5.839550   6.198385   6.250878  ...
# ...

# %% [markdown]
# # Agriculture, forestry, and fishing, value added (current US Dollars)

# %%
agriculture_value_added_usd = final_df[final_df['Indicator Name'] == 'Agriculture, forestry, and fishing, value added (current US$)']

# Exporting the DataFrame to a CSV file
agriculture_value_added_usd.to_csv('agriculture_value_added_usd.csv', index=False)

# %%
agriculture_value_added_usd.head(5)
# Out:
#     Country Name Country Code  \
# 9          Aruba          ABW
# 93   Afghanistan          AFG
# 177       Angola          AGO
# 219      Albania          ALB
# 261      Andorra          AND
#
#                                         Indicator Name  Indicator Code  \
# 9    Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD
# 93   Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD
# 177  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD
# 219  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD
# 261  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.CD
#
#              1999          2000          2001          2002          2003  \
# 9    6.603352e+06  3.486034e+05  3.530726e+05  3.541899e+05  3.681564e+05
# 93            NaN           NaN           NaN  1.477788e+09  1.691687e+09
# 177  3.870347e+08  5.171632e+08  7.288603e+08  8.926098e+08  1.104100e+09
# ...

# %% [markdown]
# # Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)

# %%
annual_freshwater_withdrawals_agriculture_percent = final_df[final_df['Indicator Name'] == 'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)']

# Exporting the DataFrame to a CSV file
annual_freshwater_withdrawals_agriculture_percent.to_csv('annual_freshwater_withdrawals_agriculture_percent.csv', index=False)

# %%
annual_freshwater_withdrawals_agriculture_percent.head(5)
# Out:
#     Country Name Country Code  \
# 10         Aruba          ABW
# 94   Afghanistan          AFG
# 178       Angola          AGO
# 220      Albania          ALB
# 262      Andorra          AND
#
#                                         Indicator Name  Indicator Code  \
# 10   Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS
# 94   Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS
# 178  Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS
# 220  Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS
# 262  Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 10         NaN        NaN        NaN        NaN        NaN        NaN  ...
# 94   98.614280  98.606201  98.518576  98.431107  98.343792  98.256633  ...
# 178  35.329415  32.786885  30.194626  27.703939  25.308969  23.004302  ...
# ...

# %% [markdown]
# # Rural population living in areas where elevation is below 5 meters (% of total population)

# %%
rural_population_below_5m_elevation_percent = final_df[final_df['Indicator Name'] == 'Rural population living in areas where elevation is below 5 meters (% of total population)']

# Exporting the DataFrame to a CSV file
rural_population_below_5m_elevation_percent.to_csv('rural_population_below_5m_elevation_percent.csv', index=False)

# %%
rural_population_below_5m_elevation_percent.head(5)
# Out:
#     Country Name Country Code  \
# 11         Aruba          ABW
# 95   Afghanistan          AFG
# 179       Angola          AGO
# 221      Albania          ALB
# 263      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 11   Rural population living in areas where elevati...  EN.POP.EL5M.RU.ZS
# 95   Rural population living in areas where elevati...  EN.POP.EL5M.RU.ZS
# 179  Rural population living in areas where elevati...  EN.POP.EL5M.RU.ZS
# 221  Rural population living in areas where elevati...  EN.POP.EL5M.RU.ZS
# 263  Rural population living in areas where elevati...  EN.POP.EL5M.RU.ZS
#
#      1999      2000  2001  2002  2003  2004  ...  2014      2015  2016  2017  \
# 11    NaN  0.583562   NaN   NaN   NaN   NaN  ...   NaN  0.391895   NaN   NaN
# 95    NaN  0.000000   NaN   NaN   NaN   NaN  ...   NaN  0.000000   NaN   NaN
# 179   NaN  0.289613   NaN   NaN   NaN   NaN  ...   NaN  0.312737   NaN   NaN
# ...

# %% [markdown]
# # Agricultural nitrous oxide emissions (% of total)

# %%
agricultural_nitrous_oxide_emissions_percent = final_df[final_df['Indicator Name'] == 'Agricultural nitrous oxide emissions (% of total)']

# Exporting the DataFrame to a CSV file
agricultural_nitrous_oxide_emissions_percent.to_csv('agricultural_nitrous_oxide_emissions_percent.csv', index=False)

# %%
agricultural_nitrous_oxide_emissions_percent.head(5)
# Out:
#     Country Name Country Code  \
# 12         Aruba          ABW
# 96   Afghanistan          AFG
# 180       Angola          AGO
# 222      Albania          ALB
# 264      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 12   Agricultural nitrous oxide emissions (% of total)  EN.ATM.NOXE.AG.ZS
# 96   Agricultural nitrous oxide emissions (% of total)  EN.ATM.NOXE.AG.ZS
# 180  Agricultural nitrous oxide emissions (% of total)  EN.ATM.NOXE.AG.ZS
# 222  Agricultural nitrous oxide emissions (% of total)  EN.ATM.NOXE.AG.ZS
# 264  Agricultural nitrous oxide emissions (% of total)  EN.ATM.NOXE.AG.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 12         NaN        NaN        NaN        NaN        NaN        NaN  ...
# 96   91.566265  90.331492  88.819876  90.000000  90.104167  90.026247  ...
# 180  98.617176  98.587571  98.551724  98.535032  98.666667  98.619547  ...
# ...

# %% [markdown]
# # Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)

# %%
agricultural_nitrous_oxide_emissions_tons = final_df[final_df['Indicator Name'] == 'Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)']

# Exporting the DataFrame to a CSV file
agricultural_nitrous_oxide_emissions_tons.to_csv('agricultural_nitrous_oxide_emissions_tons.csv', index=False)

# %%
agricultural_nitrous_oxide_emissions_tons.head(5)
# Out:
#     Country Name Country Code  \
# 13         Aruba          ABW
# 97   Afghanistan          AFG
# 181       Angola          AGO
# 223      Albania          ALB
# 265      Andorra          AND
#
#                                         Indicator Name        Indicator Code  \
# 13   Agricultural nitrous oxide emissions (thousand...  EN.ATM.NOXE.AG.KT.CE
# 97   Agricultural nitrous oxide emissions (thousand...  EN.ATM.NOXE.AG.KT.CE
# 181  Agricultural nitrous oxide emissions (thousand...  EN.ATM.NOXE.AG.KT.CE
# 223  Agricultural nitrous oxide emissions (thousand...  EN.ATM.NOXE.AG.KT.CE
# 265  Agricultural nitrous oxide emissions (thousand...  EN.ATM.NOXE.AG.KT.CE
#
#            1999        2000        2001        2002        2003        2004  \
# 13          NaN         NaN         NaN         NaN         NaN         NaN
# 97    3803.2250   3273.8578   2861.0682   3334.4114   3463.5050   3427.2086
# 181  13515.5814  13921.3978  14251.9692  15438.1880  17728.3776  17825.7938
# ...

# %% [markdown]
# # Agricultural methane emissions (% of total)

# %%
agricultural_methane_emissions_percent = final_df[final_df['Indicator Name'] == 'Agricultural methane emissions (% of total)']

# Exporting the DataFrame to a CSV file
agricultural_methane_emissions_percent.to_csv('agricultural_methane_emissions_percent.csv', index=False)

# %%
agricultural_methane_emissions_percent.head(5)
# Out:
#     Country Name Country Code                               Indicator Name  \
# 14         Aruba          ABW  Agricultural methane emissions (% of total)
# 98   Afghanistan          AFG  Agricultural methane emissions (% of total)
# 182       Angola          AGO  Agricultural methane emissions (% of total)
# 224      Albania          ALB  Agricultural methane emissions (% of total)
# 266      Andorra          AND  Agricultural methane emissions (% of total)
#
#         Indicator Code       1999       2000       2001       2002       2003  \
# 14   EN.ATM.METH.AG.ZS        NaN        NaN        NaN        NaN        NaN
# 98   EN.ATM.METH.AG.ZS  75.737152  72.804533  68.589744  73.190349  73.432056
# 182  EN.ATM.METH.AG.ZS  62.472011  62.565217  60.561056  59.877956  60.826503
# 224  EN.ATM.METH.AG.ZS  71.544715  71.466667  71.002710  70.054945  70.108696
# 266  EN.ATM.METH.AG.ZS   0.000000   0.000000   0.000000   0.000000   0.000000
#
# ...

# %% [markdown]
# # Agricultural methane emissions (thousand metric tons of CO2 equivalent)

# %%
agricultural_methane_emissions_tons = final_df[final_df['Indicator Name'] == 'Agricultural methane emissions (thousand metric tons of CO2 equivalent)']

# Exporting the DataFrame to a CSV file
agricultural_methane_emissions_tons.to_csv('agricultural_methane_emissions_tons.csv', index=False)

# %%
agricultural_methane_emissions_tons.head(5)
# Out:
#     Country Name Country Code  \
# 15         Aruba          ABW
# 99   Afghanistan          AFG
# 183       Angola          AGO
# 225      Albania          ALB
# 267      Andorra          AND
#
#                                         Indicator Name        Indicator Code  \
# 15   Agricultural methane emissions (thousand metri...  EN.ATM.METH.AG.KT.CE
# 99   Agricultural methane emissions (thousand metri...  EN.ATM.METH.AG.KT.CE
# 183  Agricultural methane emissions (thousand metri...  EN.ATM.METH.AG.KT.CE
# 225  Agricultural methane emissions (thousand metri...  EN.ATM.METH.AG.KT.CE
# 267  Agricultural methane emissions (thousand metri...  EN.ATM.METH.AG.KT.CE
#
#            1999        2000        2001        2002        2003       2004  \
# 15          NaN         NaN         NaN         NaN         NaN        NaN
# 99    8988.0175   7712.1400   6421.6875   8192.4275   8426.6375   8342.655
# 183  13952.0975  14393.4325  14680.1500  15703.5500  17806.4200  17831.685
# ...

# %% [markdown]
# # Access to electricity, rural (% of rural population)

# %%
access_to_electricity_rural_percent = final_df[final_df['Indicator Name'] == 'Access to electricity, rural (% of rural population)']

# Exporting the DataFrame to a CSV file
access_to_electricity_rural_percent.to_csv('access_to_electricity_rural_percent.csv', index=False)

# %%
access_to_electricity_rural_percent.head(5)
# Out:
#     Country Name Country Code  \
# 16         Aruba          ABW
# 100  Afghanistan          AFG
# 184       Angola          AGO
# 226      Albania          ALB
# 268      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 16   Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 100  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 184  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 226  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 268  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
#
#       1999        2000        2001        2002        2003        2004  ...  \
# 16   100.0  100.000000  100.000000  100.000000  100.000000  100.000000  ...
# 100    NaN         NaN         NaN         NaN    2.130410    7.842795  ...
# 184    NaN    3.473994    9.477077    2.759651    2.255916    1.653744  ...
# ...

# %% [markdown]
# # Cereal yield (kg per hectare)

# %%
cereal_yield_kg_per_hectare = final_df[final_df['Indicator Name'] == 'Cereal yield (kg per hectare)']

# Exporting the DataFrame to a CSV file
cereal_yield_kg_per_hectare.to_csv('cereal_yield_kg_per_hectare.csv', index=False)

# %%
cereal_yield_kg_per_hectare.head(5)
# Out:
#     Country Name Country Code                 Indicator Name  Indicator Code  \
# 17         Aruba          ABW  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 101  Afghanistan          AFG  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 185       Angola          AGO  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 227      Albania          ALB  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
# 269      Andorra          AND  Cereal yield (kg per hectare)  AG.YLD.CREL.KG
#
#        1999    2000    2001    2002    2003    2004  ...    2014    2015  \
# 17      NaN     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN
# 101  1285.7   806.3  1006.7  1669.8  1458.0  1334.8  ...  2096.6  2206.4
# 185   620.4   564.4   585.4   627.2   646.1   491.7  ...   888.2   982.4
# 227  2798.1  3175.1  3030.8  3291.9  3185.7  3466.3  ...  4892.6  4873.8
# 269     NaN     NaN     NaN     NaN     NaN     NaN  ...     NaN     NaN
#
# ...

# %% [markdown]
# # Surface area (sq. km)

# %%
surface_area_sq_km = final_df[final_df['Indicator Name'] == 'Surface area (sq. km)']

# Exporting the DataFrame to a CSV file
surface_area_sq_km.to_csv('surface_area_sq_km.csv', index=False)

# %%
surface_area_sq_km.head(5)
# Out:
#     Country Name Country Code         Indicator Name  Indicator Code  \
# 18         Aruba          ABW  Surface area (sq. km)  AG.SRF.TOTL.K2
# 102  Afghanistan          AFG  Surface area (sq. km)  AG.SRF.TOTL.K2
# 186       Angola          AGO  Surface area (sq. km)  AG.SRF.TOTL.K2
# 228      Albania          ALB  Surface area (sq. km)  AG.SRF.TOTL.K2
# 270      Andorra          AND  Surface area (sq. km)  AG.SRF.TOTL.K2
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 18       180.0      180.0      180.0      180.0      180.0      180.0  ...
# 102   652860.0   652860.0   652860.0   652860.0   652860.0   652860.0  ...
# 186  1246700.0  1246700.0  1246700.0  1246700.0  1246700.0  1246700.0  ...
# 228    28750.0    28750.0    28750.0    28750.0    28750.0    28750.0  ...
# 270      470.0      470.0      470.0      470.0      470.0      470.0  ...
#
#           2014       2015       2016       2017       2018       2019  \
# ...

# %% [markdown]
# # Livestock production index

# %%
livestock_production_index = final_df[final_df['Indicator Name'] == 'Livestock production index (2014-2016 = 100)']

# Exporting the DataFrame to a CSV file
livestock_production_index.to_csv('livestock_production_index.csv', index=False)

# %%
livestock_production_index.head(5)
# Out:
#     Country Name Country Code                                Indicator Name  \
# 19         Aruba          ABW  Livestock production index (2014-2016 = 100)
# 103  Afghanistan          AFG  Livestock production index (2014-2016 = 100)
# 187       Angola          AGO  Livestock production index (2014-2016 = 100)
# 229      Albania          ALB  Livestock production index (2014-2016 = 100)
# 271      Andorra          AND  Livestock production index (2014-2016 = 100)
#
#      Indicator Code    1999   2000   2001   2002   2003   2004  ...    2014  \
# 19   AG.PRD.LVSK.XD     NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 103  AG.PRD.LVSK.XD  115.17  98.12  78.92  95.13  90.49  97.17  ...  104.27
# 187  AG.PRD.LVSK.XD   63.17  67.62  68.84  70.71  71.37  63.59  ...   96.69
# 229  AG.PRD.LVSK.XD   76.17  80.43  82.22  84.53  87.79  90.87  ...   98.23
# 271  AG.PRD.LVSK.XD     NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
#
# ...

# %% [markdown]
# # Food production index

# %%
food_production_index = final_df[final_df['Indicator Name'] == 'Food production index (2014-2016 = 100)']

# Exporting the DataFrame to a CSV file
food_production_index.to_csv('food_production_index.csv', index=False)

# %%
food_production_index.head(5)
# Out:
#     Country Name Country Code                           Indicator Name  \
# 20         Aruba          ABW  Food production index (2014-2016 = 100)
# 104  Afghanistan          AFG  Food production index (2014-2016 = 100)
# 188       Angola          AGO  Food production index (2014-2016 = 100)
# 230      Albania          ALB  Food production index (2014-2016 = 100)
# 272      Andorra          AND  Food production index (2014-2016 = 100)
#
#      Indicator Code   1999   2000   2001   2002   2003   2004  ...    2014  \
# 20   AG.PRD.FOOD.XD    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 104  AG.PRD.FOOD.XD  79.69  67.78  61.59  74.72  76.77  74.75  ...  101.99
# 188  AG.PRD.FOOD.XD  27.58  32.16  36.90  41.72  45.12  48.23  ...   94.42
# 230  AG.PRD.FOOD.XD  60.30  63.53  65.39  65.88  69.05  72.33  ...   96.84
# 272  AG.PRD.FOOD.XD    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
#
#        2015    2016    2017    2018    2019    2020    2021    2022  2023
# ...

# %% [markdown]
# # Crop production index

# %%
crop_production_index = final_df[final_df['Indicator Name'] == 'Crop production index (2014-2016 = 100)']

# Exporting the DataFrame to a CSV file
crop_production_index.to_csv('crop_production_index.csv', index=False)

# %%
crop_production_index.head(5)
# Out:
#     Country Name Country Code                           Indicator Name  \
# 21         Aruba          ABW  Crop production index (2014-2016 = 100)
# 105  Afghanistan          AFG  Crop production index (2014-2016 = 100)
# 189       Angola          AGO  Crop production index (2014-2016 = 100)
# 231      Albania          ALB  Crop production index (2014-2016 = 100)
# 273      Andorra          AND  Crop production index (2014-2016 = 100)
#
#      Indicator Code   1999   2000   2001   2002   2003   2004  ...    2014  \
# 21   AG.PRD.CROP.XD    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 105  AG.PRD.CROP.XD  59.18  50.23  52.08  62.38  67.97  60.62  ...  100.31
# 189  AG.PRD.CROP.XD  20.90  25.49  30.81  36.20  40.15  45.52  ...   94.00
# 231  AG.PRD.CROP.XD  49.57  51.88  53.23  52.12  54.89  58.48  ...   95.94
# 273  AG.PRD.CROP.XD    NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
#
#        2015    2016    2017    2018    2019    2020    2021    2022  2023
# ...

# %% [markdown]
# # Cereal production (metric tons)

# %%
cereal_production_metric_tons = final_df[final_df['Indicator Name'] == 'Cereal production (metric tons)']

# Exporting the DataFrame to a CSV file
cereal_production_metric_tons.to_csv('cereal_production_metric_tons.csv', index=False)

# %%
cereal_production_metric_tons.head(5)
# Out:
#     Country Name Country Code                   Indicator Name  \
# 22         Aruba          ABW  Cereal production (metric tons)
# 106  Afghanistan          AFG  Cereal production (metric tons)
# 190       Angola          AGO  Cereal production (metric tons)
# 232      Albania          ALB  Cereal production (metric tons)
# 274      Andorra          AND  Cereal production (metric tons)
#
#      Indicator Code        1999       2000       2001       2002        2003  \
# 22   AG.PRD.CREL.MT         NaN        NaN        NaN        NaN         NaN
# 106  AG.PRD.CREL.MT  3256395.77  1940000.0  2108000.0  3737000.0  4381000.00
# 190  AG.PRD.CREL.MT   541183.00   519635.0   601120.0   733819.0   736542.08
# 232  AG.PRD.CREL.MT   497500.00   565800.0   502500.0   518800.0   488500.00
# 274  AG.PRD.CREL.MT         NaN        NaN        NaN        NaN         NaN
#
#            2004  ...        2014        2015        2016        2017  \
# ...

# %% [markdown]
# # Agricultural machinery, tractors per 100 sq. km of arable land

# %%
agricultural_machinery_tractors_per_100_sq_km = final_df[final_df['Indicator Name'] == 'Agricultural machinery, tractors per 100 sq. km of arable land']

# Exporting the DataFrame to a CSV file
agricultural_machinery_tractors_per_100_sq_km.to_csv('agricultural_machinery_tractors_per_100_sq_km.csv', index=False)

# %%
agricultural_machinery_tractors_per_100_sq_km.head(5)
# Out:
#     Country Name Country Code  \
# 23         Aruba          ABW
# 107  Afghanistan          AFG
# 191       Angola          AGO
# 233      Albania          ALB
# 275      Andorra          AND
#
#                                         Indicator Name  Indicator Code  \
# 23   Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS
# 107  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS
# 191  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS
# 233  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS
# 275  Agricultural machinery, tractors per 100 sq. k...  AG.LND.TRAC.ZS
#
#            1999        2000        2001        2002        2003         2004  \
# 23          NaN         NaN         NaN         NaN         NaN          NaN
# 107    0.143734    0.143173    0.132761    0.209690    0.123520     0.145855
# 191         NaN         NaN         NaN         NaN         NaN          NaN
# ...

# %% [markdown]
# # Rural land area (sq. km)

# %%
rural_land_area_sq_km = final_df[final_df['Indicator Name'] == 'Rural land area (sq. km)']

# Exporting the DataFrame to a CSV file
rural_land_area_sq_km.to_csv('rural_land_area_sq_km.csv', index=False)

# %%
rural_land_area_sq_km.head(5)
# Out:
#     Country Name Country Code            Indicator Name     Indicator Code  \
# 24         Aruba          ABW  Rural land area (sq. km)  AG.LND.TOTL.RU.K2
# 108  Afghanistan          AFG  Rural land area (sq. km)  AG.LND.TOTL.RU.K2
# 192       Angola          AGO  Rural land area (sq. km)  AG.LND.TOTL.RU.K2
# 234      Albania          ALB  Rural land area (sq. km)  AG.LND.TOTL.RU.K2
# 276      Andorra          AND  Rural land area (sq. km)  AG.LND.TOTL.RU.K2
#
#      1999          2000  2001  2002  2003  2004  ...  2014          2015  \
# 24    NaN  9.478798e+01   NaN   NaN   NaN   NaN  ...   NaN  8.480003e+01
# 108   NaN  6.378870e+05   NaN   NaN   NaN   NaN  ...   NaN  6.361732e+05
# 192   NaN  1.251981e+06   NaN   NaN   NaN   NaN  ...   NaN  1.251000e+06
# 234   NaN  2.736924e+04   NaN   NaN   NaN   NaN  ...   NaN  2.733160e+04
# 276   NaN  4.085788e+02   NaN   NaN   NaN   NaN  ...   NaN  4.094971e+02
#
#      2016  2017  2018  2019  2020  2021  2022  2023
# ...

# %% [markdown]
# # Land area (sq. km)

# %%
land_area_sq_km = final_df[final_df['Indicator Name'] == 'Land area (sq. km)']

# Exporting the DataFrame to a CSV file
land_area_sq_km.to_csv('land_area_sq_km.csv', index=False)

# %%
land_area_sq_km.head(5)
# Out:
#     Country Name Country Code      Indicator Name  Indicator Code       1999  \
# 25         Aruba          ABW  Land area (sq. km)  AG.LND.TOTL.K2      180.0
# 109  Afghanistan          AFG  Land area (sq. km)  AG.LND.TOTL.K2   652230.0
# 193       Angola          AGO  Land area (sq. km)  AG.LND.TOTL.K2  1246700.0
# 235      Albania          ALB  Land area (sq. km)  AG.LND.TOTL.K2    27400.0
# 277      Andorra          AND  Land area (sq. km)  AG.LND.TOTL.K2      470.0
#
#           2000       2001       2002       2003       2004  ...       2014  \
# 25       180.0      180.0      180.0      180.0      180.0  ...      180.0
# 109   652230.0   652230.0   652230.0   652230.0   652230.0  ...   652230.0
# 193  1246700.0  1246700.0  1246700.0  1246700.0  1246700.0  ...  1246700.0
# 235    27400.0    27400.0    27400.0    27400.0    27400.0  ...    27400.0
# 277      470.0      470.0      470.0      470.0      470.0  ...      470.0
#
# ...

# %% [markdown]
# # Average precipitation in depth (mm per year)

# %%
average_precipitation_mm_per_year = final_df[final_df['Indicator Name'] == 'Average precipitation in depth (mm per year)']

# Exporting the DataFrame to a CSV file
average_precipitation_mm_per_year.to_csv('average_precipitation_mm_per_year.csv', index=False)

# %%
average_precipitation_mm_per_year.head(5)
# Out:
#     Country Name Country Code                                Indicator Name  \
# 26         Aruba          ABW  Average precipitation in depth (mm per year)
# 110  Afghanistan          AFG  Average precipitation in depth (mm per year)
# 194       Angola          AGO  Average precipitation in depth (mm per year)
# 236      Albania          ALB  Average precipitation in depth (mm per year)
# 278      Andorra          AND  Average precipitation in depth (mm per year)
#
#      Indicator Code    1999    2000    2001    2002    2003    2004  ...  \
# 26   AG.LND.PRCP.MM     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 110  AG.LND.PRCP.MM   327.0   327.0   327.0   327.0   327.0   327.0  ...
# 194  AG.LND.PRCP.MM  1010.0  1010.0  1010.0  1010.0  1010.0  1010.0  ...
# 236  AG.LND.PRCP.MM  1485.0  1485.0  1485.0  1485.0  1485.0  1485.0  ...
# 278  AG.LND.PRCP.MM     NaN     NaN     NaN     NaN     NaN     NaN  ...
#
# ...

# %% [markdown]
# # Agricultural irrigated land (% of total agricultural land)

# %%
agricultural_irrigated_land_percent = final_df[final_df['Indicator Name'] == 'Agricultural irrigated land (% of total agricultural land)']

# Exporting the DataFrame to a CSV file
agricultural_irrigated_land_percent.to_csv('agricultural_irrigated_land_percent.csv', index=False)

# %%
agricultural_irrigated_land_percent.head(5)
# Out:
#     Country Name Country Code  \
# 27         Aruba          ABW
# 111  Afghanistan          AFG
# 195       Angola          AGO
# 237      Albania          ALB
# 279      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 27   Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 111  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 195  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 237  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
# 279  Agricultural irrigated land (% of total agricu...  AG.LND.IRIG.AG.ZS
#
#      1999  2000      2001      2002     2003      2004  ...       2014  \
# 27    NaN   NaN       NaN       NaN      NaN       NaN  ...        NaN
# 111   NaN   NaN  5.662125  4.617624  7.26428  5.499895  ...   5.742548
# 195   NaN   NaN       NaN       NaN      NaN       NaN  ...        NaN
# ...

# %% [markdown]
# # Forest area (% of land area)

# %%
forest_area_percent = final_df[final_df['Indicator Name'] == 'Forest area (% of land area)']

# Exporting the DataFrame to a CSV file
forest_area_percent.to_csv('forest_area_percent.csv', index=False)

# %%
forest_area_percent.head(5)
# Out:
#     Country Name Country Code                Indicator Name  Indicator Code  \
# 28         Aruba          ABW  Forest area (% of land area)  AG.LND.FRST.ZS
# 112  Afghanistan          AFG  Forest area (% of land area)  AG.LND.FRST.ZS
# 196       Angola          AGO  Forest area (% of land area)  AG.LND.FRST.ZS
# 238      Albania          ALB  Forest area (% of land area)  AG.LND.FRST.ZS
# 280      Andorra          AND  Forest area (% of land area)  AG.LND.FRST.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 28    2.333333   2.333333   2.333333   2.333333   2.333333   2.333333  ...
# 112   1.852782   1.852782   1.852782   1.852782   1.852782   1.852782  ...
# 196  62.456106  62.331443  61.886219  61.440995  60.995770  60.550546  ...
# 238  28.147810  28.076642  28.123248  28.169854  28.216460  28.263066  ...
# 280  34.042553  34.042553  34.042553  34.042553  34.042553  34.042553  ...
#
# ...

# %% [markdown]
# # Forest area (sq. km)

# %%
forest_area_sq_km = final_df[final_df['Indicator Name'] == 'Forest area (sq. km)']
forest_area_sq_km.head(10)

# Exporting the DataFrame to a CSV file
forest_area_sq_km.to_csv('forest_area_sq_km.csv', index=False)

# %% [markdown]
# # Rural land area where elevation is below 5 meters (% of total land area)

# %%
rural_land_area_below_5m_elevation_percent = final_df[final_df['Indicator Name'] == 'Rural land area where elevation is below 5 meters (% of total land area)']

# Exporting the DataFrame to a CSV file
rural_land_area_below_5m_elevation_percent.to_csv('rural_land_area_below_5m_elevation_percent.csv', index=False)

# %%
rural_land_area_below_5m_elevation_percent.head(5)
# Out:
#     Country Name Country Code  \
# 30         Aruba          ABW
# 114  Afghanistan          AFG
# 198       Angola          AGO
# 240      Albania          ALB
# 282      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 30   Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.ZS
# 114  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.ZS
# 198  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.ZS
# 240  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.ZS
# 282  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.ZS
#
#      1999      2000  2001  2002  2003  2004  ...  2014      2015  2016  2017  \
# 30    NaN  6.534745   NaN   NaN   NaN   NaN  ...   NaN  6.251518   NaN   NaN
# 114   NaN  0.000000   NaN   NaN   NaN   NaN  ...   NaN  0.000000   NaN   NaN
# 198   NaN  0.157532   NaN   NaN   NaN   NaN  ...   NaN  0.153368   NaN   NaN
# ...

# %% [markdown]
# # Rural land area where elevation is below 5 meters (sq. km)

# %%
rural_land_area_below_5m_elevation_sq_km = final_df[final_df['Indicator Name'] == 'Rural land area where elevation is below 5 meters (sq. km)']

# Exporting the DataFrame to a CSV file
rural_land_area_below_5m_elevation_sq_km.to_csv('rural_land_area_below_5m_elevation_sq_km.csv', index=False)

# %%
rural_land_area_below_5m_elevation_sq_km.head(5)
# Out:
#     Country Name Country Code  \
# 31         Aruba          ABW
# 115  Afghanistan          AFG
# 199       Angola          AGO
# 241      Albania          ALB
# 283      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 31   Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.K2
# 115  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.K2
# 199  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.K2
# 241  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.K2
# 283  Rural land area where elevation is below 5 met...  AG.LND.EL5M.RU.K2
#
#      1999         2000  2001  2002  2003  2004  ...  2014         2015  2016  \
# 31    NaN    11.902439   NaN   NaN   NaN   NaN  ...   NaN    11.386566   NaN
# 115   NaN     0.000000   NaN   NaN   NaN   NaN  ...   NaN     0.000000   NaN
# 199   NaN  1975.438414   NaN   NaN   NaN   NaN  ...   NaN  1923.218787   NaN
# ...

# %% [markdown]
# # Permanent cropland (% of land area)

# %%
permanent_cropland_percent = final_df[final_df['Indicator Name'] == 'Permanent cropland (% of land area)']

# Exporting the DataFrame to a CSV file
permanent_cropland_percent.to_csv('permanent_cropland_percent.csv', index=False)

# %%
permanent_cropland_percent.head(5)
# Out:
#     Country Name Country Code                       Indicator Name  \
# 32         Aruba          ABW  Permanent cropland (% of land area)
# 116  Afghanistan          AFG  Permanent cropland (% of land area)
# 200       Angola          AGO  Permanent cropland (% of land area)
# 242      Albania          ALB  Permanent cropland (% of land area)
# 284      Andorra          AND  Permanent cropland (% of land area)
#
#      Indicator Code      1999      2000      2001      2002      2003  \
# 32   AG.LND.CROP.ZS       NaN       NaN       NaN       NaN       NaN
# 116  AG.LND.CROP.ZS  0.170185  0.170185  0.171719  0.171719  0.171719
# 200  AG.LND.CROP.ZS  0.160424  0.160424  0.160424  0.160424  0.160424
# 242  AG.LND.CROP.ZS  4.452555  4.416058  4.416058  4.416058  4.416058
# 284  AG.LND.CROP.ZS       NaN       NaN       NaN       NaN       NaN
#
#          2004  ...      2014      2015      2016      2017      2018  \
# ...

# %% [markdown]
# # Land under cereal production (hectares)

# %%
land_under_cereal_production_hectares = final_df[final_df['Indicator Name'] == 'Land under cereal production (hectares)']

# Exporting the DataFrame to a CSV file
land_under_cereal_production_hectares.to_csv('land_under_cereal_production_hectares.csv', index=False)

# %%
land_under_cereal_production_hectares.head(5)
# Out:
#     Country Name Country Code                           Indicator Name  \
# 33         Aruba          ABW  Land under cereal production (hectares)
# 117  Afghanistan          AFG  Land under cereal production (hectares)
# 201       Angola          AGO  Land under cereal production (hectares)
# 243      Albania          ALB  Land under cereal production (hectares)
# 285      Andorra          AND  Land under cereal production (hectares)
#
#      Indicator Code       1999       2000       2001       2002       2003  \
# 33   AG.LND.CREL.HA        NaN        NaN        NaN        NaN        NaN
# 117  AG.LND.CREL.HA  2532871.0  2406000.0  2094000.0  2238000.0  3004700.0
# 201  AG.LND.CREL.HA   872348.0   920726.0  1026812.0  1170009.0  1140009.0
# 243  AG.LND.CREL.HA   177800.0   178200.0   165800.0   157600.0   153340.0
# 285  AG.LND.CREL.HA        NaN        NaN        NaN        NaN        NaN
#
#           2004  ...       2014       2015       2016       2017       2018  \
# ...

# %% [markdown]
# # Arable land (% of land area)

# %%
arable_land_percent = final_df[final_df['Indicator Name'] == 'Arable land (% of land area)']

# Exporting the DataFrame to a CSV file
arable_land_percent.to_csv('arable_land_percent.csv', index=False)

# %%
arable_land_percent.head(5)
# Out:
#     Country Name Country Code                Indicator Name  Indicator Code  \
# 34         Aruba          ABW  Arable land (% of land area)  AG.LND.ARBL.ZS
# 118  Afghanistan          AFG  Arable land (% of land area)  AG.LND.ARBL.ZS
# 202       Angola          AGO  Arable land (% of land area)  AG.LND.ARBL.ZS
# 244      Albania          ALB  Arable land (% of land area)  AG.LND.ARBL.ZS
# 286      Andorra          AND  Arable land (% of land area)  AG.LND.ARBL.ZS
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 34   11.111111  11.111111  11.111111  11.111111  11.111111  11.111111  ...
# 118  11.733591  11.779587  11.779587  11.771921  11.916042  11.983503  ...
# 202   2.406353   2.406353   2.406353   2.486565   2.646988   2.646988  ...
# 244  21.058394  21.094891  21.094891  21.094891  21.094891  21.094891  ...
# 286   2.127660   2.127660   1.595745   1.808511   1.829787   1.723404  ...
#
# ...

# %% [markdown]
# # Arable land (hectares per person)

# %%
arable_land_hectares_per_person = final_df[final_df['Indicator Name'] == 'Arable land (hectares per person)']

# Exporting the DataFrame to a CSV file
arable_land_hectares_per_person.to_csv('arable_land_hectares_per_person.csv', index=False)

# %%
arable_land_hectares_per_person.head(5)
# Out:
#     Country Name Country Code                     Indicator Name  \
# 35         Aruba          ABW  Arable land (hectares per person)
# 119  Afghanistan          AFG  Arable land (hectares per person)
# 203       Angola          AGO  Arable land (hectares per person)
# 245      Albania          ALB  Arable land (hectares per person)
# 287      Andorra          AND  Arable land (hectares per person)
#
#         Indicator Code      1999      2000      2001      2002      2003  \
# 35   AG.LND.ARBL.HA.PC  0.023024  0.022446  0.022053  0.021791  0.021575
# 119  AG.LND.ARBL.HA.PC  0.397293  0.393133  0.390225  0.365615  0.343208
# 203  AG.LND.ARBL.HA.PC  0.189027  0.182993  0.177079  0.176980  0.182076
# 245  AG.LND.ARBL.HA.PC  0.185603  0.187114  0.188878  0.189445  0.190156
# 287  AG.LND.ARBL.HA.PC  0.015231  0.015129  0.011059  0.011997  0.011636
#
#          2004  ...      2014      2015      2016      2017      2018  \
# ...

# %% [markdown]
# # Arable land (hectares)

# %%
arable_land_total_hectares = final_df[final_df['Indicator Name'] == 'Arable land (hectares)']

# Exporting the DataFrame to a CSV file
arable_land_total_hectares.to_csv('arable_land_total_hectares.csv', index=False)

# %%
arable_land_total_hectares.head(5)
# Out:
#     Country Name Country Code          Indicator Name  Indicator Code  \
# 36         Aruba          ABW  Arable land (hectares)  AG.LND.ARBL.HA
# 120  Afghanistan          AFG  Arable land (hectares)  AG.LND.ARBL.HA
# 204       Angola          AGO  Arable land (hectares)  AG.LND.ARBL.HA
# 246      Albania          ALB  Arable land (hectares)  AG.LND.ARBL.HA
# 288      Andorra          AND  Arable land (hectares)  AG.LND.ARBL.HA
#
#           1999       2000       2001       2002       2003       2004  ...  \
# 36      2000.0     2000.0     2000.0     2000.0     2000.0     2000.0  ...
# 120  7653000.0  7683000.0  7683000.0  7678000.0  7772000.0  7816000.0  ...
# 204  3000000.0  3000000.0  3000000.0  3100000.0  3300000.0  3300000.0  ...
# 246   577000.0   578000.0   578000.0   578000.0   578000.0   578000.0  ...
# 288     1000.0     1000.0      750.0      850.0      860.0      810.0  ...
#
#           2014       2015       2016       2017       2018       2019  \
# ...

# %% [markdown]
# # Agricultural land (% of land area)

# %%
agricultural_land_percent = final_df[final_df['Indicator Name'] == 'Agricultural land (% of land area)']

# Exporting the DataFrame to a CSV file
agricultural_land_percent.to_csv('agricultural_land_percent.csv', index=False)

# %%
agricultural_land_percent.head(5)
# Out:
#     Country Name Country Code                      Indicator Name  \
# 37         Aruba          ABW  Agricultural land (% of land area)
# 121  Afghanistan          AFG  Agricultural land (% of land area)
# 205       Angola          AGO  Agricultural land (% of land area)
# 247      Albania          ALB  Agricultural land (% of land area)
# 289      Andorra          AND  Agricultural land (% of land area)
#
#      Indicator Code       1999       2000       2001       2002       2003  \
# 37   AG.LND.AGRI.ZS  11.111111  11.111111  11.111111  11.111111  11.111111
# 121  AG.LND.AGRI.ZS  57.899821  57.945817  57.947350  57.939684  58.083805
# 205  AG.LND.AGRI.ZS  35.747975  35.712681  35.626053  35.644501  35.693431
# 247  AG.LND.AGRI.ZS  41.788321  41.751825  41.569343  41.605839  40.912409
# 289  AG.LND.AGRI.ZS  48.936170  48.936170  48.404255  48.617021  48.638298
#
#           2004  ...       2014       2015       2016       2017       2018  \
# ...

# %% [markdown]
# # Agricultural land (sq. km)

# %%
agricultural_land_sq_km = final_df[final_df['Indicator Name'] == 'Agricultural land (sq. km)']

# Exporting the DataFrame to a CSV file
agricultural_land_sq_km.to_csv('agricultural_land_sq_km.csv', index=False)

# %%
agricultural_land_sq_km.head(5)
# Out:
#     Country Name Country Code              Indicator Name  Indicator Code  \
# 38         Aruba          ABW  Agricultural land (sq. km)  AG.LND.AGRI.K2
# 122  Afghanistan          AFG  Agricultural land (sq. km)  AG.LND.AGRI.K2
# 206       Angola          AGO  Agricultural land (sq. km)  AG.LND.AGRI.K2
# 248      Albania          ALB  Agricultural land (sq. km)  AG.LND.AGRI.K2
# 290      Andorra          AND  Agricultural land (sq. km)  AG.LND.AGRI.K2
#
#          1999      2000      2001      2002      2003      2004  ...  \
# 38       20.0      20.0      20.0      20.0      20.0      20.0  ...
# 122  377640.0  377940.0  377950.0  377900.0  378840.0  379280.0  ...
# 206  445670.0  445230.0  444150.0  444380.0  444990.0  443100.0  ...
# 248   11450.0   11440.0   11390.0   11400.0   11210.0   11220.0  ...
# 290     230.0     230.0     227.5     228.5     228.6     228.1  ...
#
#          2014      2015      2016       2017       2018        2019  \
# ...

# %% [markdown]
# # Fertilizer consumption (kilograms per hectare of arable land)

# %%
fertilizer_consumption_kg_per_hectare = final_df[final_df['Indicator Name'] == 'Fertilizer consumption (kilograms per hectare of arable land)']

# Exporting the DataFrame to a CSV file
fertilizer_consumption_kg_per_hectare.to_csv('fertilizer_consumption_kg_per_hectare.csv', index=False)

# %%
fertilizer_consumption_kg_per_hectare.head(5)
# Out:
#     Country Name Country Code  \
# 39         Aruba          ABW
# 123  Afghanistan          AFG
# 207       Angola          AGO
# 249      Albania          ALB
# 291      Andorra          AND
#
#                                         Indicator Name  Indicator Code  \
# 39   Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
# 123  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
# 207  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
# 249  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
# 291  Fertilizer consumption (kilograms per hectare ...  AG.CON.FERT.ZS
#
#           1999       2000       2001       2002       2003        2004  ...  \
# 39         NaN        NaN        NaN        NaN        NaN         NaN  ...
# 123   0.653339   0.650787   2.394898   3.194390   3.478546    4.243778  ...
# 207   1.133333   0.466667        NaN   1.659032   1.788788    4.501515  ...
# ...

# %% [markdown]
# # Fertilizer consumption (% of fertilizer production)

# %%
fertilizer_consumption_percent_production = final_df[final_df['Indicator Name'] == 'Fertilizer consumption (% of fertilizer production)']

# Exporting the DataFrame to a CSV file
fertilizer_consumption_percent_production.to_csv('fertilizer_consumption_percent_production.csv', index=False)

# %%
fertilizer_consumption_percent_production.head(5)
# Out:
#     Country Name Country Code  \
# 40         Aruba          ABW
# 124  Afghanistan          AFG
# 208       Angola          AGO
# 250      Albania          ALB
# 292      Andorra          AND
#
#                                         Indicator Name     Indicator Code  \
# 40   Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
# 124  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
# 208  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
# 250  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
# 292  Fertilizer consumption (% of fertilizer produc...  AG.CON.FERT.PT.ZS
#
#       1999   2000   2001        2002        2003        2004  ...        2014  \
# 40     NaN    NaN    NaN         NaN         NaN         NaN  ...         NaN
# 124  100.0  100.0  100.0  104.751559  166.822535  170.466492  ...  495.085918
# 208    NaN    NaN    NaN         NaN         NaN         NaN  ...         NaN
# ...

# %% [markdown]
# # Agricultural machinery, tractors

# %%
agricultural_machinery_tractors_total = final_df[final_df['Indicator Name'] == 'Agricultural machinery, tractors']

# Exporting the DataFrame to a CSV file
agricultural_machinery_tractors_total.to_csv('agricultural_machinery_tractors_total.csv', index=False)

# %%
agricultural_machinery_tractors_total.head(5)
# Out:
#     Country Name Country Code                    Indicator Name  \
# 41         Aruba          ABW  Agricultural machinery, tractors
# 125  Afghanistan          AFG  Agricultural machinery, tractors
# 209       Angola          AGO  Agricultural machinery, tractors
# 251      Albania          ALB  Agricultural machinery, tractors
# 293      Andorra          AND  Agricultural machinery, tractors
#
#      Indicator Code    1999    2000    2001    2002    2003    2004  ...  \
# 41   AG.AGR.TRAC.NO     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 125  AG.AGR.TRAC.NO   110.0   110.0   102.0   161.0    96.0   114.0  ...
# 209  AG.AGR.TRAC.NO     NaN     NaN     NaN     NaN     NaN     NaN  ...
# 251  AG.AGR.TRAC.NO  8200.0  8087.0  7647.0  7515.0  5917.0  7574.0  ...
# 293  AG.AGR.TRAC.NO     NaN     NaN     NaN     NaN     NaN   354.0  ...
#
#      2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 41    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...
